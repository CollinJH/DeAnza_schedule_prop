# %%
import pandas as pd

file = 'winter_2024_data.csv'
dataframe = pd.read_csv(file)

print(dataframe)
# Out:
#      Subj    Crs Sect                           Title       Start  \
# 0    BIOL  D006A  01Y  FORM/FUNCT IN THE BIOLGCL WRLD  01/08/2024
# 1    BIOL  D006A  01Y  FORM/FUNCT IN THE BIOLGCL WRLD  01/08/2024
# 2    BIOL  D006A  02Y  FORM/FUNCT IN THE BIOLGCL WRLD  01/08/2024
# 3    BIOL  D006A  02Y  FORM/FUNCT IN THE BIOLGCL WRLD  01/08/2024
# 4    BIOL  D006B  01Y        CELL & MOLECULAR BIOLOGY  01/08/2024
# ..    ...    ...  ...                             ...         ...
# 199  PHYS  D004C  12Y  PHYS SCI/ENG:FLUID/WAVOP/THERM  01/08/2024
# 200  PHYS  D004C  12Y  PHYS SCI/ENG:FLUID/WAVOP/THERM  01/08/2024
# 201  PHYS  D004C  13Y  PHYS SCI/ENG:FLUID/WAVOP/THERM  01/08/2024
# 202  PHYS  D004C  13Y  PHYS SCI/ENG:FLUID/WAVOP/THERM  01/08/2024
# 203  PHYS  D004C  13Y  PHYS SCI/ENG:FLUID/WAVOP/THERM  01/08/2024
#
#                   Time   Days    Room Lab
# 0                  TBA    TBA  ONLINE   N
# 1    08:30 AM-11:20 AM    TTh  SC2108   Y
# 2                  TBA    TBA  ONLINE   N
# 3    11:30 AM-02:20 PM    TTh  SC2108   Y
# 4    09:30 AM-11:20 AM     MW  ONLINE   N
# ..                 ...    ...     ...  ..
# 199  02:30 PM-05:20 PM      M     S11   Y
# 200  01:30 PM-02:20 PM      F  ONLINE   N
# 201  01:30 PM-02:20 PM  MTWTh     S56   N
# 202  02:30 PM-05:20 PM      W     S11   Y
# 203  01:30 PM-02:20 PM      F  ONLINE   N
#
# [204 rows x 9 columns]

# %%
# loading the columns we need

df = dataframe[['Time', 'Days', 'Title', 'Subj', 'Crs', 'Sect', 'Lab']]

df['Lab'][50:]
# Out:
# 50     N
# 51     Y
# 52     N
# 53     Y
# 54     N
#       ..
# 199    Y
# 200    N
# 201    N
# 202    Y
# 203    N
# Name: Lab, Length: 154, dtype: object

# %%
# this code will gather the unique times for each class and load them into a list

unique_times = set()

df['String_Time'] = df['Time'].astype(str)

unique_times = set()

for time_range in df['String_Time']:
    if time_range != 'TBA' and '-' in time_range: # skip 'TBA' entries and ensure there is a dash
        # The strip() function removes any leading/trailing whitespace
        cleaned_time_range = time_range.strip()
        # Add the cleaned time range to the set
        unique_times.add(cleaned_time_range)
        
sorted_unique_times = sorted(list(unique_times))
# Out:
# /var/folders/qs/kxz_m4m10b78vfjgbs36tjb40000gn/T/ipykernel_7553/1790256648.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['String_Time'] = df['Time'].astype(str)

# %% [markdown]
# OKAY NOW WE HAVE GATHERED ALL THE UNIQUE CLASSTIMES

# %%
# with sorted_unique_times we will look for overlaps with our data

# parse the sorted_unique_time_ranges list into a list of tuples
# each containing the start and end times as datetime.time objects
# compare each time range with every other time range to check for overlaps

from datetime import datetime, timedelta

# Function to parse a time range string into start and end datetime.time objects
def parse_time_range(time_range):
    start_str, end_str = time_range.split('-')
    start = datetime.strptime(start_str.strip(), '%I:%M %p').time()
    end = datetime.strptime(end_str.strip(), '%I:%M %p').time()
    return start, end

# Function to check if two time ranges overlap
def do_times_overlap(start1, end1, start2, end2):
    return max(start1, start2) < min(end1, end2)

def do_days_overlap(days1, days2):
    days1_set = set(days1)
    days2_set = set(days2)
    return any(day in days2_set for day in days1_set)

def calculate_overlap_duration(start1, end1, start2, end2):
    # ensure overlap
    if do_times_overlap(start1, end1, start2, end2):
        
        overlap_start = max(start1, start2)
        overlap_end = min(end1, end2)
        
        overlap_start_dt = datetime.combine(datetime.today(), overlap_start)
        overlap_end_dt = datetime.combine(datetime.today(), overlap_end)
        
        duration = (overlap_end_dt - overlap_start_dt).total_seconds() / 60
        return max(0, duration)
    else:
        return
    
def extract_unique_times(class_info):
    start_times = set()
    for info in class_info:
        # assuming the same format for each entry, in this index is 1
        time_info = info[1]
        start_time = time_info.split('-')[0].strip()
        start_times.add(start_time)
    return list(start_times)
    


parsed_time_ranges = [parse_time_range(time_range) for time_range in sorted_unique_times]

# Check for overlaps
overlaps = []
for i, time_range_1 in enumerate(parsed_time_ranges):
    for j, time_range_2 in enumerate(parsed_time_ranges):
        if i < j:  # Avoid comparing the same pair twice and comparing a range with itself
            start1, end1 = time_range_1
            start2, end2 = time_range_2
            if do_times_overlap(start1, end1, start2, end2):
                overlaps.append((sorted_unique_times[i], sorted_unique_times[j]))
                
                
class_info = [
    (row['Title'], row['Time'], row['Days'], row['Subj'], row['Crs'], row['Sect'], row['Lab'])
    for _, row in df.iterrows()
    if row['Time'] != 'TBA' and row['Time'] != 'Time' and row['Subj'] != 'MATH' and row['Lab'] != 'N' and not pd.isna(row['Title']) and not pd.isna(row['Time']) and not pd.isna(row['Days'])
]

unique_class_times = extract_unique_times(class_info)

for title1, time1, days1, subj1, crs1, sect1, lab1 in class_info:
    print(f" {title1}, {time1}, {days1}, {subj1}, {crs1}, {sect1}, {lab1}")

unique_class_times
# Out:
#  FORM/FUNCT IN THE BIOLGCL WRLD, 08:30 AM-11:20 AM, TTh, BIOL, D006A, 01Y, Y
#  FORM/FUNCT IN THE BIOLGCL WRLD, 11:30 AM-02:20 PM, TTh, BIOL, D006A, 02Y, Y
#  CELL & MOLECULAR BIOLOGY, 09:30 AM-12:20 PM, TTh, BIOL, D006B, 01Y, Y
#  CELL & MOLECULAR BIOLOGY, 01:30 PM-04:20 PM, TTh, BIOL, D006B, 02Y, Y
#  CELL & MOLECULAR BIOLOGY, 10:30 AM-01:20 PM, MW, BIOL, D006B, 03Y, Y
#  CELL & MOLECULAR BIOLOGY, 01:30 PM-04:20 PM, MW, BIOL, D006B, 04Y, Y
#  CELL & MOLECULAR BIOLOGY, 01:30 PM-04:20 PM, MW, BIOL, D006B, 05Y, Y
#  CELL & MOLECULAR BIOLOGY, 04:30 PM-07:20 PM, MW, BIOL, D006B, 06Y, Y
#  CELL & MOLECULAR BIOLOGY, 09:30 AM-12:20 PM, TTh, BIOL, D006B, 07Y, Y
#  CELL & MOLECULAR BIOLOGY, 01:30 PM-04:20 PM, TTh, BIOL, D006B, 08Y, Y
#  CELL & MOLECULAR BIOLOGY, 10:30 AM-01:20 PM, MW, BIOL, D006B, 09Y, Y
#  PHYS SCIEN/ENG:ELCTRCTY/MAGNET, 10:30 AM-01:20 PM, Th, PHYS, D004B, 12Y, Y
#  PHYS SCIEN/ENG:ELCTRCTY/MAGNET, 02:30 PM-05:20 PM, T, PHYS, D004B, 20Y, Y
#  PHYS SCIEN/ENG:ELCTRCTY/MAGNET, 02:30 PM-05:20 PM, Th, PHYS, D004B, 21Y, Y
#  PHYS SCIEN/ENG:ELCTRCTY/MAGNET, 07:55 PM-10:45 PM, M, PHYS, D004B, 60, Y
#  PHYS SCIEN/ENG:ELCTRCTY/MAGNET, 07:45 PM-10:45 PM, W, PHYS, D004B, 61, Y
#  PHYS SCI/ENG:FLUID/WAVOP/THERM, 10:30 AM-01:20 PM, T, PHYS, D004C, 11Y, Y
#  PHYS SCI/ENG:FLUID/WAVOP/THERM, 02:30 PM-05:20 PM, M, PHYS, D004C, 12Y, Y
#  PHYS SCI/ENG:FLUID/WAVOP/THERM, 02:30 PM-05:20 PM, W, PHYS, D004C, 13Y, Y
# ['01:30 PM',
#  '09:30 AM',
#  '08:30 AM',
#  '04:30 PM',
#  '10:30 AM',
#  '11:30 AM',
#  '07:30 PM',
#  '02:30 PM',
#  '08:00 PM',
#  '07:55 PM',
#  '07:45 PM',
#  '07:30 AM']

# %%
# need to add logic for section

import itertools

evaluated_pairs = set() # set to save when two sections have been identified as overlapping to eliminate redundency

title_overlaps = []
for (title1, time1, days1, subj1, crs1, sect1, lab1), (title2, time2, days2, subj2, crs2, sect2, lab2) in itertools.combinations(class_info, 2):
    if title1 == title2:
        continue
    if subj1 == subj2:
        continue
    if crs1 == crs2:
        continue
    if sect1 == sect2:
        continue
        
    sorted_sect_pair = tuple(sorted((sect1, sect2)))
    
    if sorted_sect_pair in evaluated_pairs:
        continue
        
    start1, end1 = parse_time_range(time1)
    start2, end2 = parse_time_range(time2)
    # first check if the times overlap
    if do_times_overlap(start1, end1, start2, end2):
        # now check if the days overlap
        if do_days_overlap(days1, days2):
            calculated_duration = overlap_duration = calculate_overlap_duration(start1, end1, start2, end2)
            title_overlaps.append((title1, time1, days1, subj1, sect1, crs1, title2, time2, days2, subj2, sect2, crs2, calculated_duration))
            evaluated_pairs.add(sorted_sect_pair)

counter = 0
for overlap in title_overlaps:
    print(f"{overlap[1]}, {overlap[4]}, {overlap[5]}, {overlap[3]} - overlaps - {overlap[7]}, {overlap[10]}, {overlap[11]}, {overlap[9]} ")
    counter += 1
    
print(f"There are a total of {counter} overlaps")

unique_class_times
# Out:
# 08:30 AM-11:20 AM, 01Y, D006A, BIOL - overlaps - 07:30 AM-10:20 AM, 03, D001A, CHEM
# 08:30 AM-11:20 AM, 01Y, D006A, BIOL - overlaps - 10:30 AM-01:20 PM, 13Y, D004A, PHYS
# 08:30 AM-11:20 AM, 01Y, D006A, BIOL - overlaps - 10:30 AM-01:20 PM, 10Y, D004B, PHYS
# 08:30 AM-11:20 AM, 01Y, D006A, BIOL - overlaps - 10:30 AM-01:20 PM, 12Y, D004B, PHYS
# 08:30 AM-11:20 AM, 01Y, D006A, BIOL - overlaps - 10:30 AM-01:20 PM, 11Y, D004C, PHYS
#  '07:30 AM']

# %% [markdown]
# <b> VISUALIZING THE DATA </b>

# %%
import matplotlib.pyplot as plt

# loading the amount of overlaps for each class title
overlap_count = {}

overlap_count = {}
for overlap in title_overlaps:
    overlap_count[overlap[0]] = overlap_count.get(overlap[0], 0) + 1
    overlap_count[overlap[6]] = overlap_count.get(overlap[6], 0) + 1

# Sort the titles by their overlap count
sorted_titles = sorted(overlap_count, key=overlap_count.get, reverse=True)
sorted_counts = [overlap_count[title] for title in sorted_titles]

plt.figure(figsize=(10, 8))
plt.bar(sorted_titles, sorted_counts, color="skyblue")

plt.title("Overlaps per Class")
plt.xlabel("Class Title")
plt.ylabel("Overlaps")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# <b> comments about data </b> <br>
#     - The functionality of this, allows for EACH CLASS to be checked against every single other entry
#     - The function skips classes that have the same Title, CRN, and Subject
#     - with 205 data points in this example, there will be a large number of pairs to check
#     - we can calculate the maximum number of unique cominbations of pairs that can be formed
#
#     n * (n - 1) / 2
#     - where n is the total number of items in a set
#     205 * 204 / 2 = 20910 pairs, our result of 1317 overlaps is reasonable
#
#     difference between time conflicts, start times to end times
#     two specific departments
#
#
#
#
#     GOAL
#
#     propose for the lab schedules across departments come together for synchronized lab times
#
#     only labs
#     Spring 2023 - Winter 2024
#     determine start times
#     how many labs

# %%
class_info
# Out:
# [('FORM/FUNCT IN THE BIOLGCL WRLD',
#   '08:30 AM-11:20 AM',
#   'TTh',
#   'BIOL',
#   'D006A',
#   '01Y'),
#  ('FORM/FUNCT IN THE BIOLGCL WRLD',
#   '11:30 AM-02:20 PM',
#   'TTh',
#   'BIOL',
#   'D006A',
#   '02Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '09:30 AM-11:20 AM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '01Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '09:30 AM-12:20 PM',
#   'TTh',
#   'BIOL',
#   'D006B',
#   '01Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '09:30 AM-11:20 AM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '02Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '01:30 PM-04:20 PM',
#   'TTh',
#   'BIOL',
#   'D006B',
#   '02Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '10:30 AM-01:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '03Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '01:30 PM-04:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '04Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '01:30 PM-04:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '05Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '04:30 PM-07:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '06Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '10:30 AM-12:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '07Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '09:30 AM-12:20 PM',
#   'TTh',
#   'BIOL',
#   'D006B',
#   '07Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '10:30 AM-12:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '08Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '01:30 PM-04:20 PM',
#   'TTh',
#   'BIOL',
#   'D006B',
#   '08Y'),
#  ('CELL & MOLECULAR BIOLOGY',
#   '10:30 AM-01:20 PM',
#   'MW',
#   'BIOL',
#   'D006B',
#   '09Y'),
#  ('GENERAL CHEMISTRY', '12:30 PM-01:45 PM', 'MW', 'CHEM', 'D001A', '01'),
#  ('GENERAL CHEMISTRY', '08:30 AM-11:20 AM', 'MW', 'CHEM', 'D001A', '01'),
#  ('GENERAL CHEMISTRY', '12:30 PM-01:45 PM', 'MW', 'CHEM', 'D001A', '02'),
#  ('GENERAL CHEMISTRY', '02:30 PM-05:20 PM', 'MW', 'CHEM', 'D001A', '02'),
#  ('GENERAL CHEMISTRY', '10:30 AM-11:45 AM', 'TTh', 'CHEM', 'D001A', '03'),
#  ('GENERAL CHEMISTRY', '07:30 AM-10:20 AM', 'TTh', 'CHEM', 'D001A', '03'),
#  ('GENERAL CHEMISTRY', '04:30 PM-05:45 PM', 'TTh', 'CHEM', 'D001A', '25'),
#  ('GENERAL CHEMISTRY', '11:30 AM-02:20 PM', 'MW', 'CHEM', 'D001A', '25'),
#  ('GENERAL CHEMISTRY', '04:30 PM-05:45 PM', 'TTh', 'CHEM', 'D001A', '26'),
#  ('GENERAL CHEMISTRY', '11:30 AM-02:20 PM', 'TTh', 'CHEM', 'D001A', '26'),
#  ('GENERAL CHEMISTRY', '06:00 PM-07:15 PM', 'TTh', 'CHEM', 'D001A', '53'),
#  ('GENERAL CHEMISTRY', '02:30 PM-05:20 PM', 'TTh', 'CHEM', 'D001A', '53'),
#  ('GENERAL CHEMISTRY', '06:00 PM-07:15 PM', 'TTh', 'CHEM', 'D001A', '54'),
#  ('GENERAL CHEMISTRY', '07:30 PM-10:20 PM', 'TTh', 'CHEM', 'D001A', '54'),
#  ('GENERAL CHEMISTRY', '12:30 PM-01:45 PM', 'MW', 'CHEM', 'D001B', '01'),
#  ('GENERAL CHEMISTRY', '08:30 AM-11:20 AM', 'MW', 'CHEM', 'D001B', '01'),
#  ('GENERAL CHEMISTRY', '12:30 PM-01:45 PM', 'MW', 'CHEM', 'D001B', '02'),
#  ('GENERAL CHEMISTRY', '02:30 PM-05:20 PM', 'MW', 'CHEM', 'D001B', '02'),
#  ('GENERAL CHEMISTRY', '10:30 AM-11:45 AM', 'TTh', 'CHEM', 'D001B', '03'),
#  ('GENERAL CHEMISTRY', '07:30 AM-10:20 AM', 'TTh', 'CHEM', 'D001B', '03'),
#  ('GENERAL CHEMISTRY', '10:30 AM-11:45 AM', 'TTh', 'CHEM', 'D001B', '04'),
#  ('GENERAL CHEMISTRY', '02:30 PM-05:20 PM', 'TTh', 'CHEM', 'D001B', '04'),
#  ('GENERAL CHEMISTRY', '11:30 AM-12:45 PM', 'MW', 'CHEM', 'D001B', '08'),
#  ('GENERAL CHEMISTRY', '08:30 AM-11:20 AM', 'MW', 'CHEM', 'D001B', '08'),
#  ('GENERAL CHEMISTRY', '11:30 AM-12:45 PM', 'MW', 'CHEM', 'D001B', '09'),
#  ('GENERAL CHEMISTRY', '02:30 PM-05:20 PM', 'MW', 'CHEM', 'D001B', '09'),
#  ('GENERAL CHEMISTRY', '04:30 PM-05:45 PM', 'TTh', 'CHEM', 'D001B', '25'),
#  ('GENERAL CHEMISTRY', '11:30 AM-02:20 PM', 'MW', 'CHEM', 'D001B', '25'),
#  ('GENERAL CHEMISTRY', '04:30 PM-05:45 PM', 'TTh', 'CHEM', 'D001B', '26'),
#  ('GENERAL CHEMISTRY', '11:30 AM-02:20 PM', 'TTh', 'CHEM', 'D001B', '26'),
#  ('GENERAL CHEMISTRY', '06:00 PM-07:15 PM', 'TTh', 'CHEM', 'D001B', '66'),
#  ('GENERAL CHEMISTRY', '07:30 PM-10:20 PM', 'TTh', 'CHEM', 'D001B', '66'),
#  ('GEN CHEM/QUAL ANALYSIS', '03:30 PM-04:45 PM', 'MW', 'CHEM', 'D001C', '11'),
#  ('GEN CHEM/QUAL ANALYSIS', '08:30 AM-11:20 AM', 'MW', 'CHEM', 'D001C', '11'),
#  ('GEN CHEM/QUAL ANALYSIS', '03:30 PM-04:45 PM', 'MW', 'CHEM', 'D001C', '12'),
#  ('GEN CHEM/QUAL ANALYSIS', '11:30 AM-02:20 PM', 'MW', 'CHEM', 'D001C', '12'),
#  ('ORGANIC CHEMISTRY', '06:00 PM-07:15 PM', 'TTh', 'CHEM', 'D012A', '53'),
#  ('ORGANIC CHEMISTRY', '02:30 PM-05:20 PM', 'TTh', 'CHEM', 'D012A', '53'),
#  ('ORGANIC CHEMISTRY', '06:00 PM-07:15 PM', 'TTh', 'CHEM', 'D012A', '54'),
#  ('ORGANIC CHEMISTRY', '07:30 PM-10:20 PM', 'TTh', 'CHEM', 'D012A', '54'),
#  ('ORGANIC CHEMISTRY', '11:30 AM-12:45 PM', 'MW', 'CHEM', 'D012B', '01'),
#  ('ORGANIC CHEMISTRY', '07:30 AM-10:20 AM', 'MW', 'CHEM', 'D012B', '01'),
#  ('ORGANIC CHEMISTRY', '11:30 AM-12:45 PM', 'MW', 'CHEM', 'D012B', '02'),
#  ('ORGANIC CHEMISTRY', '02:30 PM-05:20 PM', 'MW', 'CHEM', 'D012B', '02'),
#  ('ORGANIC CHEMISTRY', '12:30 PM-01:45 PM', 'TTh', 'CHEM', 'D012B', '03'),
#  ('ORGANIC CHEMISTRY', '08:30 AM-11:20 AM', 'TTh', 'CHEM', 'D012B', '03'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004A',
#   '12Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '10:30 AM-01:20 PM',
#   'M',
#   'PHYS',
#   'D004A',
#   '12Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004A',
#   '12Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004A',
#   '13Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004A',
#   '13Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '10:30 AM-01:20 PM',
#   'T',
#   'PHYS',
#   'D004A',
#   '13Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004A',
#   '14Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '10:30 AM-01:20 PM',
#   'W',
#   'PHYS',
#   'D004A',
#   '14Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004A',
#   '14Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004A',
#   '22Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '02:30 PM-05:20 PM',
#   'T',
#   'PHYS',
#   'D004A',
#   '22Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004A',
#   '22Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004A',
#   '24Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '02:30 PM-05:20 PM',
#   'Th',
#   'PHYS',
#   'D004A',
#   '24Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004A',
#   '24Y'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '05:30 PM-07:45 PM',
#   'MW',
#   'PHYS',
#   'D004A',
#   '60'),
#  ('PHYS SCIENT/ENG:MECHANCS', '08:00 PM-10:55 PM', 'W', 'PHYS', 'D004A', '60'),
#  ('PHYS SCIENT/ENG:MECHANCS',
#   '05:30 PM-07:45 PM',
#   'MW',
#   'PHYS',
#   'D004A',
#   '62'),
#  ('PHYS SCIENT/ENG:MECHANCS', '08:00 PM-10:55 PM', 'M', 'PHYS', 'D004A', '62'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004B',
#   '10Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '10:30 AM-01:20 PM',
#   'T',
#   'PHYS',
#   'D004B',
#   '10Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004B',
#   '10Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004B',
#   '12Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '10:30 AM-01:20 PM',
#   'Th',
#   'PHYS',
#   'D004B',
#   '12Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004B',
#   '12Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004B',
#   '20Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '02:30 PM-05:20 PM',
#   'T',
#   'PHYS',
#   'D004B',
#   '20Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004B',
#   '20Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004B',
#   '21Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '02:30 PM-05:20 PM',
#   'Th',
#   'PHYS',
#   'D004B',
#   '21Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004B',
#   '21Y'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '05:30 PM-07:45 PM',
#   'MW',
#   'PHYS',
#   'D004B',
#   '60'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '07:55 PM-10:45 PM',
#   'M',
#   'PHYS',
#   'D004B',
#   '60'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '05:30 PM-07:45 PM',
#   'MW',
#   'PHYS',
#   'D004B',
#   '61'),
#  ('PHYS SCIEN/ENG:ELCTRCTY/MAGNET',
#   '07:45 PM-10:45 PM',
#   'W',
#   'PHYS',
#   'D004B',
#   '61'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '09:30 AM-10:20 AM',
#   'MTWTh',
#   'PHYS',
#   'D004C',
#   '11Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '09:30 AM-10:20 AM',
#   'F',
#   'PHYS',
#   'D004C',
#   '11Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '10:30 AM-01:20 PM',
#   'T',
#   'PHYS',
#   'D004C',
#   '11Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004C',
#   '12Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '02:30 PM-05:20 PM',
#   'M',
#   'PHYS',
#   'D004C',
#   '12Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004C',
#   '12Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '01:30 PM-02:20 PM',
#   'MTWTh',
#   'PHYS',
#   'D004C',
#   '13Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '02:30 PM-05:20 PM',
#   'W',
#   'PHYS',
#   'D004C',
#   '13Y'),
#  ('PHYS SCI/ENG:FLUID/WAVOP/THERM',
#   '01:30 PM-02:20 PM',
#   'F',
#   'PHYS',
#   'D004C',
#   '13Y')]
